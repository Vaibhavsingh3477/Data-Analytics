# %%
import math

def calculate_distance(point1, point2):
    """
    Calculate the distance between two points in 2D space.

    Parameters:
    point1 (tuple): The first point as a tuple (x1, y1).
    point2 (tuple): The second point as a tuple (x2, y2).

    Returns:
    float: The distance between the two points.
    """
    x1, y1 = point1
    x2, y2 = point2
    distance = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
    return distance


print(calculate_distance((0, 0), (3, 4)))  # Output: 5.0
# Out:
# 5.0

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt, pow, pi

print(sqrt(25))  # Output: 5.0
print(pow(2, 3))  # Output: 8.0
print(pi)  # Output: 3.141592653589793
# Out:
# 5.0
# 8.0
# 3.141592653589793

# %%
import numpy as np

# %%
import sys
print(sys.executable)
# Out:
# d:\anaconda3\envs\venv\python.exe

# %%
# !pip install numpy

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.4

# %%
import numpy as np
array = np.array([1, 2, 3, 4, 5])
print(array)  # Output: [1 2 3 4 5]
# Out:
# [1 2 3 4 5]

# %%
from math import *

# %%
print(sqrt(25))  # Output: 5.0
print(pow(2, 3))  # Output: 8.0    
print(pi)  # Output: 3.141592653589793
# Out:
# 5.0
# 8.0
# 3.141592653589793

# %%
from package.maths import *
import package.maths as maths

maths.add(5, 3)        # Output: 8
maths.subtract(5, 3)   # Output: 2
maths.multiply(5, 3)   # Output: 15
# Out:
# 15

# %%
print(maths.subtract(5, 3))   # Output: 2
# Out:
# 2
