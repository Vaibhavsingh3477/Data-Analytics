# %%
import os

# %%
new_directory="new_directory"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created successfully.")
# Out:
# Directory 'new_directory' created successfully.

# %%
# listing files and directories
current_directory=os.getcwd()
print(f"Current Directory: {current_directory}")
# Out:
# Current Directory: d:\DATA ANALYST\PYTHON\File Handling

# %%
# listing files and directories

items = os.listdir(current_directory)
print("Items in the current directory:")
for item in items:
    print(item)
# Out:
# Items in the current directory:
# example.bin
# example.txt
# fileoperations.ipynb
# filepath.ipynb
# new_directory
# output.txt

# %%
### Joining Paths

dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(f"Full Path: {full_path}")
# Out:
# Full Path: d:\DATA ANALYST\PYTHON\File Handling\folder\file.txt

# %%
path='example1.txt'
if os.path.exists(path):
    print(f'The file {path} exists.')
else:
    print(f'The file {path} does not exist.')
# Out:
# The file example1.txt does not exist.

# %%
### checking if a path is a file or a directory

path='example1.txt'
if os.path.isfile(path):
    print(f'{path} is a file.') 
elif os.path.isdir(path):
    print(f'{path} is a directory.')
else:
    print(f'{path} does not exist.')
# Out:
# example.txt is a file.

# %%
### Getting the absolute path

relative_path='example1.txt'
absolute_path=os.path.abspath(relative_path)
print(f'Absolute path: {absolute_path}')
# Out:
# Absolute path: d:\DATA ANALYST\PYTHON\File Handling\example1.txt
